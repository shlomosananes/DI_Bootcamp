# %% [markdown]
# <a href="https://colab.research.google.com/github/shlomosananes/DI_Bootcamp/blob/master/Week04_Day03_Exercise_XP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exercise 1 : Import A File From Kaggle**
#
# Instructions
#
# - Import the titanic dataset that you can find on Kaggle.
# - Print the first few rows of the DataFrame.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import userdata
import os

os.environ["KAGGLE_KEY"] = userdata.get('KAGGLE_KEY')
os.environ["KAGGLE_USERNAME"] = userdata.get('KAGGLE_USERNAME')

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory

# %%
# !kaggle competitions download -c titanic
# !unzip titanic.zip
# Out:
# ...
#   0% 0.00/34.1k [00:00<?, ?B/s]
# 100% 34.1k/34.1k [00:00<00:00, 48.1MB/s]
# Archive:  titanic.zip
#   inflating: gender_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %%
import pandas as pd
train_data = pd.read_csv('train.csv')

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # **Exercise 2: Importing A CSV File**
#
# Instructions
#
# - Use the Iris Dataset CSV.
#   1. Download the Iris dataset CSV file and place it in the same directory as your Jupyter Notebook.
#   2. Import the CSV file using Pandas.
#   3. Display the first five rows of the dataset.

# %%
import pandas as pd
iris = pd.read_csv('iris.data.csv',header=None)

# %%
iris.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %% [markdown]
# # **Exercise 3: Reading JSON Data**
#
# Instructions
#
# - Use a sample JSON dataset
#
# 1. Import the JSON data from the provided URL.
# 2. Use Pandas to read the JSON data.
# 3. Display the first five entries of the data.

# %%
json_data = pd.read_json('https://jsonplaceholder.typicode.com/posts')
json_data.head()
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %% [markdown]
# # **Exercise 4: Loading Data From An Excel File**
#
# Instructions
#
# - Take this excel file for practice.
# 1.  Download the sample Excel file and place it in your working directory.
# 2.  Use Pandas to read the Excel file.
# 3.  Display the first few rows of the data.

# %%
excel_data = pd.read_excel('dummy_data_excel.xlsx', index_col=0)
excel_data.head()
# Out:
#          Age  Salary
# Name
# Alice     25   50000
# Bob       30   60000
# Charlie   35   70000
# David     28   55000
# Emily     32   62000

# %% [markdown]
# # **Exercise 5 : Export A Dataframe To Excel Format And JSON Format.**
#
# Instructions
#
# - Create a simple dataframe.
# - Export the dataframe to an excel file.
# - Export the dataframe to a JSON file.

# %%
import pandas as pd
df = pd.DataFrame({
    'Name':['Shlomo','Saul','Murilo','Daniel','Igor','Rafael'],
    'Country':['Israel','Israel','US','Brazil','Brazil','Brazil'],
    'Birthdate':['1989-11-07','1989-03-29','1989-06-03','1990-06-03','1989-04-27','1988-10-27']
    })

# %%
#Export to CSV
df.to_csv('ex5_on_csv.csv',index=False)

# %%
#Export to JSON
df.to_json('ex5_on_json.json')
